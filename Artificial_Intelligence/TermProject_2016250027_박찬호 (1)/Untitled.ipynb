# %%
import os
import urllib
import pandas as pd
import tarfile
import matplotlib.pyplot as plt
import numpy as np
from pandas.plotting import scatter_matrix


DOWNLOAD_ROOT = "http://cksgh9206.dothome.co.kr/"
FIRES_PATH = os.path.join("datasets", "sanbul")
FIRES_URL = DOWNLOAD_ROOT + "datasets/sanbul/sanbul-5.tgz"
def fetch_fires_data(fires_url=FIRES_URL, fires_path=FIRES_PATH):
    if not os.path.isdir(fires_path):
        os.makedirs(fires_path)
    tgz_path = os.path.join(fires_path, "sanbul-5.tgz")
    urllib.request.urlretrieve(fires_url, tgz_path)
    fires_tgz = tarfile.open(tgz_path)
    fires_tgz.extractall(path=fires_path)
    fires_tgz.close()

fetch_fires_data()

def load_fires_data(fires_path=FIRES_PATH):
    csv_path = os.path.join(fires_path, "sanbul-5.csv")
    return pd.read_csv(csv_path)

fires = load_fires_data()

"""
print("################ fires.head\n")
print(fires.head())
print("################ fires.info\n")
print(fires.info())
print("################ fires.describe")
print(fires.describe())

month = fires.month.value_counts()
print("################ month")
print(month)
print("################ day")
day = fires.day.value_counts()
print(day)
"""
plt.subplot(331)
plt.hist(fires.avg_temp, bins=80)
plt.title('avg_temp')
plt.subplot(332)
plt.hist(fires.avg_wind, bins=80)
plt.title('avg_wind')
plt.subplot(333)
plt.hist(fires.burned_area, bins=80)
plt.title('burned_area')
plt.subplot(334)
plt.hist(fires.latitude, bins=80)
plt.title('latitude')
plt.subplot(335)
plt.hist(fires.longitude, bins=80)
plt.title('longitude')
plt.subplot(336)
plt.hist(fires.max_temp, bins=80)
plt.title('max_Temp')
plt.subplot(337)
plt.hist(fires.max_wind_speed, bins=80)
plt.title('max_wind_speed')
plt.tight_layout()
plt.show()


plt.subplot(121)
plt.hist(fires.burned_area, bins=50)
plt.title('burned_area')
plt.subplot(122)
plt.hist(np.log(fires.burned_area+1), bins=50)
plt.title('ln(burned_area+1)')
plt.tight_layout()
plt.show()

from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(fires, test_size=0.2, shuffle=True, random_state=42)

test_set.head()

fires["month"].hist()
plt.tight_layout()
plt.show()

from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, test_index in split.split(fires, fires["month"]):
    strat_train_set = fires.loc[train_index]
    strat_test_set = fires.loc[test_index]

print("\nMonth category proportion: \n",
strat_test_set["month"].value_counts()/len(strat_test_set))

print("\nOverall month category proportion: \n",
fires["month"].value_counts()/len(fires))


fires_df = pd.DataFrame(data=fires, columns=['burned_area', 'max_temp', 'avg_temp', 'max_wind_speed'])
scatter_matrix(fires_df, alpha=0.5, figsize=(8, 8), diagonal='hist')
plt.show()

fires.plot(kind="scatter", x="longitude", y="latitude", alpha=0.4,s=fires["max_temp"], label="max_temp",c="burned_area", cmap=plt.get_cmap("jet"), colorbar=True)
plt.show()

corr_matrix = fires.corr()
print("Looking for correlations\nCORR_MATRIX :")
print(corr_matrix["burned_area"].sort_values(ascending=False))

from sklearn.preprocessing import OneHotEncoder
cat_encoder = OneHotEncoder()

fires = strat_train_set.drop(["burned_area"], axis = 1)
fires_labels = strat_train_set["burned_area"].copy()

cat_day_encoder = cat_encoder.fit_transform(fires[["day"]])
print("cat_day_encoder :\n", cat_day_encoder)
print("cat_day_encoder.categories : ", cat_encoder.categories_)

cat_month_encoder = cat_encoder.fit_transform(fires[["month"]])
print("cat_month_encoder :\n", cat_month_encoder)
print("cat_month_encoder.categories : ", cat_encoder.categories_)


print("\n\n########################################################################")
print("Now let's build a pipeline for preprocessing the numerical attributes:")
fires_num = fires.drop(["month", "day"], axis=1)

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

num_pipeline = Pipeline([
('std_scaler', StandardScaler()),
])
from sklearn.compose import ColumnTransformer
num_attribs = list(fires_num)
cat_attribs = ["month", "day"]

full_pipeline = ColumnTransformer([
("num", num_pipeline, num_attribs),
("cat", OneHotEncoder(), cat_attribs),
])
fires_prepared = full_pipeline.fit_transform(fires)

print(fires_prepared)

print("#########################################################2")
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR


#sgd
X = fires_prepared
y = fires_labels
from sklearn.linear_model import SGDRegressor
sgd_reg = SGDRegressor(max_iter=10000, tol=1e-3, penalty=None, eta0=0.1)
sgd_reg.fit(fires_prepared, fires_labels)

params = {
    'alpha': 10.0 ** -np.arange(1, 7),
    'loss': ['squared_loss', 'huber', 'epsilon_insensitive'],
    'penalty': ['l2', 'l1', 'elasticnet'],
    'learning_rate': ['constant', 'optimal', 'invscaling'],
}

grid_search_cv = GridSearchCV(sgd_reg, params, verbose=1, cv=10)

grid_search_cv.fit(fires_prepared, fires_labels)

sgd_best_model = grid_search_cv.best_estimator_

print("best_estimator : ", sgd_best_model)

def plot_learning_curves(model, X, y):
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=10)
    train_errors, val_errors = [], []
    for m in range(1, len(X_train)):
        model.fit(X_train[:m], y_train[:m])
        y_train_predict = model.predict(X_train[:m])
        y_val_predict = model.predict(X_val)
        train_errors.append(mean_squared_error(y_train_predict, y_train[:m]))
        val_errors.append(mean_squared_error(y_val_predict, y_val))

plot_learning_curves(sgd_reg, X, y)



from sklearn.metrics import mean_squared_error
fires_predictions = sgd_reg.predict(fires_prepared)
sgd_mse = mean_squared_error(fires_labels, fires_predictions)
sgd_rmse = np.sqrt(sgd_mse)
# revert into the original value: y=ln(burned_area+1) => burned_area = exp(y)-1
sgd_rmse_reverted = np.exp(sgd_rmse)-1
print("\nLR - RMSE(train set):\n", sgd_rmse_reverted)

















import tensorflow as tf
from tensorflow import keras
from sklearn.datasets import make_moons

X_train, X_test, y_train, y_test = train_test_split(fires_prepared, fires_labels, test_size=0.2,
random_state=42)


np.random.seed(42)
tf.random.set_seed(42)

mlp_model = keras.models.Sequential([
    keras.layers.Dense(30, activation="relu", input_shape=X_train.shape[1:]),
    keras.layers.Dense(1, activation="relu"),
])

mlp_model.compile(loss="mean_squared_error", optimizer=keras.optimizers.SGD(lr=1e-3))

history = mlp_model.fit(X_train, y_train, epochs=200, validation_data=(X_valid, y_valid))
mse_test = mlp_model.evaluate(X_test, y_test)
X_new = X_test[:10]
y_pred = mlp_model.predict(X_new)

plt.plot(pd.DataFrame(history.history))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

model =mlp_model
model_version = "0001"
model_name = "my_fires_model"
model_path = os.path.join( model_name, model_version)
tf.saved_model.save(model, model_path)
# Out:
# Month category proportion:
#  03-Mar    0.369565
# 04-Apr    0.217391
# 02-Feb    0.097826
# 06-Jun    0.086957
# 05-May    0.076087
# 11-Nov    0.032609
# 01-Jan    0.032609
# 09-Sep    0.021739
# 10-Oct    0.021739
# 12-Dec    0.021739
# 08-Aug    0.010870
# 07-Jul    0.010870
# Name: month, dtype: float64
#
# Overall month category proportion:
#  03-Mar    0.375000
# 04-Apr    0.219298
# 02-Feb    0.098684
# 06-Jun    0.087719
# 05-May    0.081140
# 01-Jan    0.032895
# 11-Nov    0.030702
# 12-Dec    0.019737
# 10-Oct    0.017544
# 09-Sep    0.017544
# 08-Aug    0.010965
# 07-Jul    0.008772
# Name: month, dtype: float64
# D:\anaconda3\lib\site-packages\matplotlib\collections.py:857: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# Looking for correlations
# CORR_MATRIX :
# burned_area       1.000000
# longitude         0.104925
# max_temp          0.092222
# latitude          0.080654
# avg_temp          0.065841
# max_wind_speed    0.060394
# avg_wind          0.018909
# Name: burned_area, dtype: float64
# cat_day_encoder :
#    (0, 5)	1.0
#   (1, 2)	1.0
#   (2, 3)	1.0
#   (3, 2)	1.0
#   (4, 3)	1.0
#   (5, 6)	1.0
#   (6, 1)	1.0
#   (7, 7)	1.0
#   (8, 7)	1.0
#   (9, 4)	1.0
#   (10, 6)	1.0
#   (11, 2)	1.0
#   (12, 6)	1.0
#   (13, 3)	1.0
#   (14, 3)	1.0
#   (15, 3)	1.0
#   (16, 1)	1.0
#   (17, 6)	1.0
#   (18, 7)	1.0
#   (19, 1)	1.0
#   (20, 0)	1.0
#   (21, 6)	1.0
#   (22, 6)	1.0
#   (23, 0)	1.0
#   (24, 5)	1.0
#   :	:
#   (339, 2)	1.0
#   (340, 1)	1.0
#   (341, 0)	1.0
#   (342, 1)	1.0
#   (343, 0)	1.0
#   (344, 0)	1.0
#   (345, 0)	1.0
#   (346, 6)	1.0
#   (347, 5)	1.0
#   (348, 3)	1.0
#   (349, 3)	1.0
#   (350, 4)	1.0
#   (351, 4)	1.0
#   (352, 2)	1.0
#   (353, 3)	1.0
#   (354, 5)	1.0
#   (355, 0)	1.0
#   (356, 1)	1.0
#   (357, 3)	1.0
#   (358, 5)	1.0
#   (359, 2)	1.0
#   (360, 5)	1.0
#   (361, 2)	1.0
#   (362, 3)	1.0
#   (363, 2)	1.0
# cat_day_encoder.categories :  [array(['00-sun', '01-mon', '02-tue', '03-wed', '04-thu', '05-fri',
#        '06-sat', '07-hol'], dtype=object)]
# cat_month_encoder :
#    (0, 3)	1.0
#   (1, 5)	1.0
#   (2, 3)	1.0
#   (3, 3)	1.0
#   (4, 2)	1.0
#   (5, 2)	1.0
#   (6, 3)	1.0
#   (7, 8)	1.0
#   (8, 8)	1.0
#   (9, 4)	1.0
#   (10, 2)	1.0
#   (11, 4)	1.0
#   (12, 10)	1.0
#   (13, 2)	1.0
#   (14, 3)	1.0
#   (15, 2)	1.0
#   (16, 5)	1.0
#   (17, 2)	1.0
#   (18, 4)	1.0
#   (19, 1)	1.0
#   (20, 2)	1.0
#   (21, 2)	1.0
#   (22, 3)	1.0
#   (23, 3)	1.0
#   (24, 1)	1.0
#   :	:
#   (339, 4)	1.0
#   (340, 10)	1.0
#   (341, 5)	1.0
#   (342, 3)	1.0
#   (343, 0)	1.0
#   (344, 3)	1.0
#   (345, 1)	1.0
#   (346, 3)	1.0
#   (347, 3)	1.0
#   (348, 4)	1.0
#   (349, 2)	1.0
#   (350, 1)	1.0
#   (351, 9)	1.0
#   (352, 3)	1.0
#   (353, 3)	1.0
#   (354, 3)	1.0
#   (355, 2)	1.0
#   (356, 1)	1.0
#   (357, 2)	1.0
#   (358, 3)	1.0
#   (359, 4)	1.0
#   (360, 2)	1.0
#   (361, 2)	1.0
#   (362, 2)	1.0
#   (363, 2)	1.0
# cat_month_encoder.categories :  [array(['01-Jan', '02-Feb', '03-Mar', '04-Apr', '05-May', '06-Jun',
#        '07-Jul', '08-Aug', '09-Sep', '10-Oct', '11-Nov', '12-Dec'],
#       dtype=object)]
#
#
# ########################################################################
# Now let's build a pipeline for preprocessing the numerical attributes:
# [[ 1.57238451 -0.82962957  0.44533466 ...  1.          0.
#    0.        ]
#  [-0.81733668  0.20170363  1.79577391 ...  0.          0.
#    0.        ]
#  [ 0.54252478  0.111668    0.22435369 ...  0.          0.
#    0.        ]
#  ...
#  [-1.60511765 -1.12081678  0.33484418 ...  0.          0.
#    0.        ]
#  [-1.06300201 -1.07035545 -1.12608555 ...  0.          0.
#    0.        ]
#  [-1.08866791 -1.92813657  0.02792617 ...  0.          0.
#    0.        ]]
# #########################################################2
# Fitting 10 folds for each of 162 candidates, totalling 1620 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1184: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# [Parallel(n_jobs=1)]: Done 1620 out of 1620 | elapsed:   24.0s finished
# best_estimator :  SGDRegressor(alpha=0.01, average=False, early_stopping=False, epsilon=0.1,
#              eta0=0.1, fit_intercept=True, l1_ratio=0.15,
#              learning_rate='optimal', loss='epsilon_insensitive',
#              max_iter=10000, n_iter_no_change=5, penalty='l1', power_t=0.25,
#              random_state=None, shuffle=True, tol=0.001,
#              validation_fraction=0.1, verbose=0, warm_start=False)
#
# LR - RMSE(train set):
#  0.6730036013183038
# Epoch 1/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.4787 - val_loss: 2.2490
# Epoch 2/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4648 - val_loss: 2.2002
# Epoch 3/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4530 - val_loss: 2.1587
# Epoch 4/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4433 - val_loss: 2.1199
# Epoch 5/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4345 - val_loss: 2.0834
# Epoch 6/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4264 - val_loss: 2.0481
# Epoch 7/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4190 - val_loss: 2.0385
# Epoch 8/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4187 - val_loss: 2.0057
# Epoch 9/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4120 - val_loss: 1.9770
# Epoch 10/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4063 - val_loss: 1.9572
# Epoch 11/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4024 - val_loss: 1.9257
# Epoch 12/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3961 - val_loss: 1.8999
# Epoch 13/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3914 - val_loss: 1.8685
# Epoch 14/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3860 - val_loss: 1.8468
# Epoch 15/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3822 - val_loss: 1.8279
# Epoch 16/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3789 - val_loss: 1.8084
# Epoch 17/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3757 - val_loss: 1.7841
# Epoch 18/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3720 - val_loss: 1.7647
# Epoch 19/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3689 - val_loss: 1.7423
# Epoch 20/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3657 - val_loss: 1.7237
# Epoch 21/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3631 - val_loss: 1.7083
# Epoch 22/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3610 - val_loss: 1.6959
# Epoch 23/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3595 - val_loss: 1.6781
# Epoch 24/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3571 - val_loss: 1.6642
# Epoch 25/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3554 - val_loss: 1.6529
# Epoch 26/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3542 - val_loss: 1.6383
# Epoch 27/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3525 - val_loss: 1.6282
# Epoch 28/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3514 - val_loss: 1.6166
# Epoch 29/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3502 - val_loss: 1.6063
# Epoch 30/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3492 - val_loss: 1.5968
# Epoch 31/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3484 - val_loss: 1.5904
# Epoch 32/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3477 - val_loss: 1.5805
# Epoch 33/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3468 - val_loss: 1.5689
# Epoch 34/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3458 - val_loss: 1.5612
# Epoch 35/200
# 10/10 [==============================] - ETA: 0s - loss: 0.138 - 0s 2ms/step - loss: 0.3450 - val_loss: 1.5518
# Epoch 36/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3443 - val_loss: 1.5453
# Epoch 37/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3437 - val_loss: 1.5418
# Epoch 38/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3434 - val_loss: 1.5335
# Epoch 39/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3427 - val_loss: 1.5274
# Epoch 40/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3422 - val_loss: 1.5181
# Epoch 41/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3415 - val_loss: 1.5090
# Epoch 42/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3409 - val_loss: 1.5021
# Epoch 43/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3404 - val_loss: 1.4984
# Epoch 44/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3401 - val_loss: 1.4922
# Epoch 45/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3397 - val_loss: 1.4869
# Epoch 46/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3393 - val_loss: 1.4811
# Epoch 47/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3390 - val_loss: 1.4750
# Epoch 48/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3385 - val_loss: 1.4714
# Epoch 49/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3382 - val_loss: 1.4687
# Epoch 50/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3379 - val_loss: 1.4639
# Epoch 51/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3376 - val_loss: 1.4598
# Epoch 52/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3373 - val_loss: 1.4546
# Epoch 53/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3369 - val_loss: 1.4521
# Epoch 54/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3366 - val_loss: 1.4468
# Epoch 55/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3364 - val_loss: 1.4421
# Epoch 56/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3360 - val_loss: 1.4389
# Epoch 57/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3358 - val_loss: 1.4350
# Epoch 58/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3354 - val_loss: 1.4323
# Epoch 59/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3352 - val_loss: 1.4255
# Epoch 60/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3349 - val_loss: 1.4219
# Epoch 61/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3347 - val_loss: 1.4186
# Epoch 62/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3344 - val_loss: 1.4151
# Epoch 63/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3342 - val_loss: 1.4120
# Epoch 64/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3340 - val_loss: 1.4078
# Epoch 65/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3337 - val_loss: 1.4060
# Epoch 66/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3335 - val_loss: 1.4046
# Epoch 67/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3332 - val_loss: 1.3998
# Epoch 68/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3328 - val_loss: 1.3960
# Epoch 69/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3326 - val_loss: 1.3936
# Epoch 70/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3324 - val_loss: 1.3895
# Epoch 71/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3321 - val_loss: 1.3866
# Epoch 72/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3319 - val_loss: 1.3780
# Epoch 73/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3316 - val_loss: 1.3754
# Epoch 74/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3313 - val_loss: 1.3729
# Epoch 75/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3312 - val_loss: 1.3703
# Epoch 76/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3309 - val_loss: 1.3676
# Epoch 77/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3307 - val_loss: 1.3659
# Epoch 78/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3305 - val_loss: 1.3636
# Epoch 79/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3303 - val_loss: 1.3614
# Epoch 80/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3301 - val_loss: 1.3600
# Epoch 81/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3299 - val_loss: 1.3578
# Epoch 82/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3298 - val_loss: 1.3527
# Epoch 83/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3295 - val_loss: 1.3509
# Epoch 84/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3293 - val_loss: 1.3469
# Epoch 85/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3292 - val_loss: 1.3463
# Epoch 86/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3288 - val_loss: 1.3424
# Epoch 87/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3286 - val_loss: 1.3412
# Epoch 88/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3285 - val_loss: 1.3406
# Epoch 89/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3283 - val_loss: 1.3376
# Epoch 90/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3281 - val_loss: 1.3351
# Epoch 91/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3279 - val_loss: 1.3325
# Epoch 92/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3277 - val_loss: 1.3306
# Epoch 93/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3275 - val_loss: 1.3318
# Epoch 94/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3272 - val_loss: 1.3273
# Epoch 95/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3270 - val_loss: 1.3252
# Epoch 96/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3269 - val_loss: 1.3235
# Epoch 97/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3266 - val_loss: 1.3222
# Epoch 98/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3265 - val_loss: 1.3197
# Epoch 99/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3264 - val_loss: 1.3177
# Epoch 100/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3262 - val_loss: 1.3154
# Epoch 101/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3260 - val_loss: 1.3139
# Epoch 102/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3258 - val_loss: 1.3144
# Epoch 103/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3256 - val_loss: 1.3137
# Epoch 104/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3255 - val_loss: 1.3110
# Epoch 105/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3254 - val_loss: 1.3096
# Epoch 106/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3252 - val_loss: 1.3085
# Epoch 107/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3250 - val_loss: 1.3057
# Epoch 108/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3248 - val_loss: 1.3042
# Epoch 109/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3246 - val_loss: 1.3034
# Epoch 110/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3244 - val_loss: 1.3005
# Epoch 111/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3243 - val_loss: 1.2988
# Epoch 112/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3241 - val_loss: 1.2972
# Epoch 113/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3239 - val_loss: 1.2955
# Epoch 114/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3237 - val_loss: 1.2949
# Epoch 115/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3236 - val_loss: 1.2926
# Epoch 116/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3234 - val_loss: 1.2913
# Epoch 117/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3232 - val_loss: 1.2903
# Epoch 118/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3231 - val_loss: 1.2868
# Epoch 119/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3229 - val_loss: 1.2840
# Epoch 120/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3227 - val_loss: 1.2813
# Epoch 121/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3226 - val_loss: 1.2779
# Epoch 122/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3225 - val_loss: 1.2755
# Epoch 123/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3223 - val_loss: 1.2737
# Epoch 124/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3222 - val_loss: 1.2743
# Epoch 125/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3220 - val_loss: 1.2729
# Epoch 126/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3218 - val_loss: 1.2715
# Epoch 127/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3216 - val_loss: 1.2693
# Epoch 128/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3215 - val_loss: 1.2684
# Epoch 129/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3213 - val_loss: 1.2688
# Epoch 130/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3212 - val_loss: 1.2677
# Epoch 131/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3211 - val_loss: 1.2654
# Epoch 132/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3210 - val_loss: 1.2653
# Epoch 133/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3208 - val_loss: 1.2635
# Epoch 134/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3206 - val_loss: 1.2617
# Epoch 135/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3205 - val_loss: 1.2614
# Epoch 136/200
# 10/10 [==============================] - ETA: 0s - loss: 0.516 - 0s 2ms/step - loss: 0.3203 - val_loss: 1.2604
# Epoch 137/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3202 - val_loss: 1.2593
# Epoch 138/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3200 - val_loss: 1.2586
# Epoch 139/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3199 - val_loss: 1.2567
# Epoch 140/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3197 - val_loss: 1.2546
# Epoch 141/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3195 - val_loss: 1.2510
# Epoch 142/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3195 - val_loss: 1.2502
# Epoch 143/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3193 - val_loss: 1.2493
# Epoch 144/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3191 - val_loss: 1.2478
# Epoch 145/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3190 - val_loss: 1.2455
# Epoch 146/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3189 - val_loss: 1.2440
# Epoch 147/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3188 - val_loss: 1.2432
# Epoch 148/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3186 - val_loss: 1.2423
# Epoch 149/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3184 - val_loss: 1.2412
# Epoch 150/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3183 - val_loss: 1.2407
# Epoch 151/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3180 - val_loss: 1.2401
# Epoch 152/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3179 - val_loss: 1.2403
# Epoch 153/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3176 - val_loss: 1.2393
# Epoch 154/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3175 - val_loss: 1.2391
# Epoch 155/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3173 - val_loss: 1.2402
# Epoch 156/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3171 - val_loss: 1.2400
# Epoch 157/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3169 - val_loss: 1.2419
# Epoch 158/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3168 - val_loss: 1.2397
# Epoch 159/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3167 - val_loss: 1.2384
# Epoch 160/200
# 10/10 [==============================] - ETA: 0s - loss: 0.561 - 0s 2ms/step - loss: 0.3165 - val_loss: 1.2364
# Epoch 161/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3163 - val_loss: 1.2342
# Epoch 162/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3162 - val_loss: 1.2342
# Epoch 163/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3160 - val_loss: 1.2326
# Epoch 164/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3158 - val_loss: 1.2316
# Epoch 165/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3157 - val_loss: 1.2321
# Epoch 166/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3156 - val_loss: 1.2308
# Epoch 167/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3155 - val_loss: 1.2295
# Epoch 168/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3153 - val_loss: 1.2280
# Epoch 169/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3151 - val_loss: 1.2262
# Epoch 170/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3150 - val_loss: 1.2257
# Epoch 171/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3148 - val_loss: 1.2241
# Epoch 172/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3146 - val_loss: 1.2230
# Epoch 173/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3146 - val_loss: 1.2198
# Epoch 174/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3144 - val_loss: 1.2180
# Epoch 175/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3143 - val_loss: 1.2174
# Epoch 176/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3142 - val_loss: 1.2155
# Epoch 177/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3139 - val_loss: 1.2136
# Epoch 178/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3138 - val_loss: 1.2119
# Epoch 179/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3137 - val_loss: 1.2143
# Epoch 180/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3136 - val_loss: 1.2136
# Epoch 181/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3134 - val_loss: 1.2119
# Epoch 182/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3133 - val_loss: 1.2109
# Epoch 183/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3132 - val_loss: 1.2092
# Epoch 184/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3130 - val_loss: 1.2083
# Epoch 185/200
# 10/10 [==============================] - ETA: 0s - loss: 1.329 - 0s 2ms/step - loss: 0.3129 - val_loss: 1.2074
# Epoch 186/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3127 - val_loss: 1.2095
# Epoch 187/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3126 - val_loss: 1.2084
# Epoch 188/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3125 - val_loss: 1.2061
# Epoch 189/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3123 - val_loss: 1.2061
# Epoch 190/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3122 - val_loss: 1.2027
# Epoch 191/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3120 - val_loss: 1.2015
# Epoch 192/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3119 - val_loss: 1.1997
# Epoch 193/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3118 - val_loss: 1.1987
# Epoch 194/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3117 - val_loss: 1.1966
# Epoch 195/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3116 - val_loss: 1.1957
# Epoch 196/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3115 - val_loss: 1.1946
# Epoch 197/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3113 - val_loss: 1.1939
# Epoch 198/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3113 - val_loss: 1.1921
# Epoch 199/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3111 - val_loss: 1.1922
# Epoch 200/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3110 - val_loss: 1.1896
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2037
# WARNING:tensorflow:11 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002CF9F2C94C0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# INFO:tensorflow:Assets written to: my_fires_model\0001\assets

# %%
def plot_learning_curves(model, X, y):
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=10)
    train_errors, val_errors = [], []
    for m in range(1, len(X_train)):
        model.fit(X_train[:m], y_train[:m])
        y_train_predict = model.predict(X_train[:m])
        y_val_predict = model.predict(X_val)
        train_errors.append(mean_squared_error(y_train_predict, y_train[:m]))
        val_errors.append(mean_squared_error(y_val_predict, y_val))
    plt.plot(np.sqrt(train_errors), "r-+", linewidth=2, label="train")
    plt.plot(np.sqrt(val_errors), "b-", linewidth=3, label="val")
    plt.legend(loc="upper right", fontsize=14)  # not shown in the book
    plt.xlabel("Training set size", fontsize=14)  # not shown
    plt.ylabel("RMSE", fontsize=14)

plot_learning_curves(sgd_reg, X, y)
plt.axis([0, 80, 0, 3])
plt.show()

from sklearn.metrics import mean_squared_error
fires_predictions = sgd_reg.predict(fires_prepared)
sgd_mse = mean_squared_error(fires_labels, fires_predictions)
sgd_rmse = np.sqrt(sgd_mse)
# revert into the original value: y=ln(burned_area+1) => burned_area = exp(y)-1
sgd_rmse_reverted = np.exp(sgd_rmse)-1
print("\nLR - RMSE(train set):\n", sgd_rmse_reverted)

from sklearn.model_selection import cross_val_score

sgd_scores = cross_val_score(sgd_reg, fires_prepared, fires_labels,
scoring="neg_mean_squared_error", cv=10)

fires_train_prepared, fires_test_prepared, fires_train_labels, fires_test_labels = train_test_split(fires_prepared, fires_labels, test_size=0.2,
random_state=42)

def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())

sgd_rmse_scores = np.sqrt(-sgd_scores)
print("\nLinear Regression scores (train set): \n")
display_scores(sgd_rmse_scores)


sgd_scores = cross_val_score(sgd_reg, fires_test_prepared, fires_test_labels,
scoring="neg_mean_squared_error", cv=10)
lin_rmse_scores = np.sqrt(-sgd_scores)
print("\nLinear Regression scores (test set): \n")
display_scores(lin_rmse_scores)














import tensorflow as tf
from tensorflow import keras
from sklearn.datasets import make_moons

X_train, X_valid, y_train, y_valid = train_test_split(fires_prepared, fires_labels, test_size=0.2,
random_state=42)
fires_train_prepared, fires_test_prepared, fires_train_labels, fires_test_labels = train_test_split(fires_prepared, fires_labels, test_size=0.2,
random_state=42)
X_test = fires_test_prepared
y_test = fires_test_labels

np.random.seed(42)
tf.random.set_seed(42)

mlp_model = keras.models.Sequential([
    keras.layers.Dense(30, activation="relu", input_shape=X_train.shape[1:]),
    keras.layers.Dense(1, activation="relu"),
])

mlp_model.compile(loss="mean_squared_error", optimizer=keras.optimizers.SGD(lr=1e-3))

history = mlp_model.fit(X_train, y_train, epochs=200, validation_data=(X_valid, y_valid))
mse_test = mlp_model.evaluate(X_test, y_test)
X_new = X_test[:10]
y_pred = mlp_model.predict(X_new)

plt.plot(pd.DataFrame(history.history))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

model =mlp_model
model_version = "0001"
model_name = "my_fires_model"
model_path = os.path.join( model_name, model_version)
tf.saved_model.save(model, model_path)
# Out:
# LR - RMSE(train set):
#  0.7006873670355174
#
# Linear Regression scores (train set):
#
# Scores: [0.5788787  0.38476168 0.39303745 0.27295716 0.66647067 0.44851894
#  1.11508499 0.25781346 0.41823941 0.23466692]
# Mean: 0.4770429371746019
# Standard deviation: 0.24932989677684658
#
# Linear Regression scores (test set):
#
# Scores: [0.30544012 0.27061287 1.06592864 0.39369111 0.21091951 0.32824565
#  0.39187326 0.41308378 0.31999627 0.42128453]
# Mean: 0.412107574239471
# Standard deviation: 0.2270921399052708
# Epoch 1/200
# 10/10 [==============================] - 0s 10ms/step - loss: 0.4787 - val_loss: 0.3825
# Epoch 2/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4648 - val_loss: 0.3687
# Epoch 3/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4530 - val_loss: 0.3577
# Epoch 4/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4433 - val_loss: 0.3472
# Epoch 5/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4345 - val_loss: 0.3377
# Epoch 6/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4264 - val_loss: 0.3287
# Epoch 7/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4190 - val_loss: 0.3283
# Epoch 8/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4187 - val_loss: 0.3203
# Epoch 9/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4120 - val_loss: 0.3134
# Epoch 10/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4063 - val_loss: 0.3089
# Epoch 11/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4024 - val_loss: 0.3017
# Epoch 12/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3961 - val_loss: 0.2961
# Epoch 13/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3914 - val_loss: 0.2894
# Epoch 14/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3860 - val_loss: 0.2849
# Epoch 15/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3822 - val_loss: 0.2811
# Epoch 16/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3789 - val_loss: 0.2773
# Epoch 17/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3757 - val_loss: 0.2730
# Epoch 18/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3720 - val_loss: 0.2692
# Epoch 19/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3689 - val_loss: 0.2647
# Epoch 20/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3657 - val_loss: 0.2617
# Epoch 21/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3631 - val_loss: 0.2591
# Epoch 22/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3610 - val_loss: 0.2572
# Epoch 23/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3595 - val_loss: 0.2549
# Epoch 24/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3571 - val_loss: 0.2529
# Epoch 25/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3554 - val_loss: 0.2514
# Epoch 26/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3542 - val_loss: 0.2490
# Epoch 27/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3525 - val_loss: 0.2477
# Epoch 28/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3514 - val_loss: 0.2463
# Epoch 29/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3502 - val_loss: 0.2450
# Epoch 30/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3492 - val_loss: 0.2440
# Epoch 31/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3484 - val_loss: 0.2432
# Epoch 32/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3477 - val_loss: 0.2422
# Epoch 33/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3468 - val_loss: 0.2408
# Epoch 34/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3458 - val_loss: 0.2399
# Epoch 35/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3450 - val_loss: 0.2387
# Epoch 36/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3443 - val_loss: 0.2380
# Epoch 37/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3437 - val_loss: 0.2376
# Epoch 38/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3434 - val_loss: 0.2367
# Epoch 39/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3427 - val_loss: 0.2360
# Epoch 40/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3422 - val_loss: 0.2348
# Epoch 41/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3415 - val_loss: 0.2334
# Epoch 42/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3409 - val_loss: 0.2327
# Epoch 43/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3404 - val_loss: 0.2324
# Epoch 44/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3401 - val_loss: 0.2317
# Epoch 45/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3397 - val_loss: 0.2312
# Epoch 46/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3393 - val_loss: 0.2307
# Epoch 47/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3390 - val_loss: 0.2302
# Epoch 48/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3385 - val_loss: 0.2298
# Epoch 49/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3382 - val_loss: 0.2296
# Epoch 50/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3379 - val_loss: 0.2292
# Epoch 51/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3376 - val_loss: 0.2287
# Epoch 52/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3373 - val_loss: 0.2283
# Epoch 53/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3369 - val_loss: 0.2281
# Epoch 54/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3366 - val_loss: 0.2277
# Epoch 55/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3364 - val_loss: 0.2273
# Epoch 56/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3360 - val_loss: 0.2269
# Epoch 57/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3358 - val_loss: 0.2266
# Epoch 58/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3354 - val_loss: 0.2263
# Epoch 59/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3352 - val_loss: 0.2257
# Epoch 60/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3349 - val_loss: 0.2254
# Epoch 61/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3347 - val_loss: 0.2250
# Epoch 62/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3344 - val_loss: 0.2247
# Epoch 63/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3342 - val_loss: 0.2244
# Epoch 64/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3340 - val_loss: 0.2241
# Epoch 65/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3337 - val_loss: 0.2239
# Epoch 66/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3335 - val_loss: 0.2235
# Epoch 67/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3332 - val_loss: 0.2231
# Epoch 68/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3328 - val_loss: 0.2229
# Epoch 69/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3326 - val_loss: 0.2227
# Epoch 70/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3324 - val_loss: 0.2224
# Epoch 71/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3321 - val_loss: 0.2222
# Epoch 72/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3319 - val_loss: 0.2217
# Epoch 73/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3316 - val_loss: 0.2214
# Epoch 74/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3313 - val_loss: 0.2212
# Epoch 75/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3312 - val_loss: 0.2210
# Epoch 76/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3309 - val_loss: 0.2207
# Epoch 77/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3307 - val_loss: 0.2206
# Epoch 78/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3305 - val_loss: 0.2204
# Epoch 79/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3303 - val_loss: 0.2202
# Epoch 80/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3301 - val_loss: 0.2200
# Epoch 81/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3299 - val_loss: 0.2198
# Epoch 82/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3298 - val_loss: 0.2193
# Epoch 83/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3295 - val_loss: 0.2191
# Epoch 84/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3293 - val_loss: 0.2189
# Epoch 85/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3292 - val_loss: 0.2188
# Epoch 86/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3288 - val_loss: 0.2185
# Epoch 87/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3286 - val_loss: 0.2184
# Epoch 88/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3285 - val_loss: 0.2183
# Epoch 89/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3283 - val_loss: 0.2181
# Epoch 90/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3281 - val_loss: 0.2179
# Epoch 91/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3279 - val_loss: 0.2177
# Epoch 92/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3277 - val_loss: 0.2175
# Epoch 93/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3275 - val_loss: 0.2173
# Epoch 94/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3272 - val_loss: 0.2171
# Epoch 95/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3270 - val_loss: 0.2169
# Epoch 96/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3269 - val_loss: 0.2167
# Epoch 97/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3266 - val_loss: 0.2165
# Epoch 98/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3265 - val_loss: 0.2164
# Epoch 99/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3264 - val_loss: 0.2163
# Epoch 100/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3262 - val_loss: 0.2160
# Epoch 101/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3260 - val_loss: 0.2159
# Epoch 102/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3258 - val_loss: 0.2158
# Epoch 103/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3256 - val_loss: 0.2157
# Epoch 104/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3255 - val_loss: 0.2156
# Epoch 105/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3254 - val_loss: 0.2154
# Epoch 106/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3252 - val_loss: 0.2153
# Epoch 107/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3250 - val_loss: 0.2151
# Epoch 108/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3248 - val_loss: 0.2149
# Epoch 109/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3246 - val_loss: 0.2148
# Epoch 110/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3244 - val_loss: 0.2146
# Epoch 111/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3243 - val_loss: 0.2145
# Epoch 112/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3241 - val_loss: 0.2144
# Epoch 113/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3239 - val_loss: 0.2141
# Epoch 114/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3237 - val_loss: 0.2138
# Epoch 115/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3236 - val_loss: 0.2137
# Epoch 116/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3234 - val_loss: 0.2135
# Epoch 117/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3232 - val_loss: 0.2134
# Epoch 118/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3231 - val_loss: 0.2130
# Epoch 119/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3229 - val_loss: 0.2128
# Epoch 120/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3227 - val_loss: 0.2127
# Epoch 121/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3226 - val_loss: 0.2126
# Epoch 122/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3225 - val_loss: 0.2124
# Epoch 123/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3223 - val_loss: 0.2123
# Epoch 124/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3222 - val_loss: 0.2122
# Epoch 125/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3220 - val_loss: 0.2121
# Epoch 126/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3218 - val_loss: 0.2120
# Epoch 127/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3216 - val_loss: 0.2119
# Epoch 128/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3215 - val_loss: 0.2118
# Epoch 129/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3213 - val_loss: 0.2117
# Epoch 130/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3212 - val_loss: 0.2115
# Epoch 131/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3211 - val_loss: 0.2114
# Epoch 132/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3210 - val_loss: 0.2113
# Epoch 133/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3208 - val_loss: 0.2112
# Epoch 134/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3206 - val_loss: 0.2111
# Epoch 135/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3205 - val_loss: 0.2110
# Epoch 136/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3203 - val_loss: 0.2109
# Epoch 137/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3202 - val_loss: 0.2108
# Epoch 138/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3200 - val_loss: 0.2106
# Epoch 139/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3199 - val_loss: 0.2104
# Epoch 140/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3197 - val_loss: 0.2102
# Epoch 141/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3195 - val_loss: 0.2100
# Epoch 142/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3195 - val_loss: 0.2099
# Epoch 143/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3193 - val_loss: 0.2098
# Epoch 144/200
# 10/10 [==============================] - ETA: 0s - loss: 0.295 - 0s 2ms/step - loss: 0.3191 - val_loss: 0.2097
# Epoch 145/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3190 - val_loss: 0.2095
# Epoch 146/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3189 - val_loss: 0.2094
# Epoch 147/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3188 - val_loss: 0.2093
# Epoch 148/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3186 - val_loss: 0.2092
# Epoch 149/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3184 - val_loss: 0.2091
# Epoch 150/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3183 - val_loss: 0.2089
# Epoch 151/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3180 - val_loss: 0.2088
# Epoch 152/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3179 - val_loss: 0.2087
# Epoch 153/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3176 - val_loss: 0.2085
# Epoch 154/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3175 - val_loss: 0.2084
# Epoch 155/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3173 - val_loss: 0.2083
# Epoch 156/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3171 - val_loss: 0.2082
# Epoch 157/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3169 - val_loss: 0.2087
# Epoch 158/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3168 - val_loss: 0.2084
# Epoch 159/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3167 - val_loss: 0.2083
# Epoch 160/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3165 - val_loss: 0.2082
# Epoch 161/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3163 - val_loss: 0.2079
# Epoch 162/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3162 - val_loss: 0.2078
# Epoch 163/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3160 - val_loss: 0.2077
# Epoch 164/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3158 - val_loss: 0.2075
# Epoch 165/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3157 - val_loss: 0.2075
# Epoch 166/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3156 - val_loss: 0.2074
# Epoch 167/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3155 - val_loss: 0.2072
# Epoch 168/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3153 - val_loss: 0.2071
# Epoch 169/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3151 - val_loss: 0.2070
# Epoch 170/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3150 - val_loss: 0.2070
# Epoch 171/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3148 - val_loss: 0.2067
# Epoch 172/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3146 - val_loss: 0.2066
# Epoch 173/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3146 - val_loss: 0.2064
# Epoch 174/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3144 - val_loss: 0.2063
# Epoch 175/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3143 - val_loss: 0.2061
# Epoch 176/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3142 - val_loss: 0.2060
# Epoch 177/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3139 - val_loss: 0.2058
# Epoch 178/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3138 - val_loss: 0.2056
# Epoch 179/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3137 - val_loss: 0.2057
# Epoch 180/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3136 - val_loss: 0.2056
# Epoch 181/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3134 - val_loss: 0.2056
# Epoch 182/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3133 - val_loss: 0.2054
# Epoch 183/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3132 - val_loss: 0.2054
# Epoch 184/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3130 - val_loss: 0.2053
# Epoch 185/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3129 - val_loss: 0.2052
# Epoch 186/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3127 - val_loss: 0.2053
# Epoch 187/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3126 - val_loss: 0.2052
# Epoch 188/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3125 - val_loss: 0.2051
# Epoch 189/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3123 - val_loss: 0.2050
# Epoch 190/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3122 - val_loss: 0.2048
# Epoch 191/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3120 - val_loss: 0.2047
# Epoch 192/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3119 - val_loss: 0.2046
# Epoch 193/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3118 - val_loss: 0.2043
# Epoch 194/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3117 - val_loss: 0.2042
# Epoch 195/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3116 - val_loss: 0.2041
# Epoch 196/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3115 - val_loss: 0.2041
# Epoch 197/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3113 - val_loss: 0.2040
# Epoch 198/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3113 - val_loss: 0.2039
# Epoch 199/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3111 - val_loss: 0.2039
# Epoch 200/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3110 - val_loss: 0.2037
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3363WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0010s). Check your callbacks.
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2037
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002CFA0EDE1F0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# INFO:tensorflow:Assets written to: my_fires_model\0001\assets
